# %% [markdown]
# #### import numpy as np
# from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#YOU CAN USE ANY EMOTION MODEL FOR YOUR FACE RECOGNITION PROJECT. I USED "ANGRY and SURPRISE FACES" IN MY OWN PROJECT.
#JUST SET YOUR DATASET LOCATION AND CHANGE THE LABEL NAMES.

# %%
train_data_dir = r"Angry and Surprised Faces Dataset Path"
validation_data_dir = r"Angry and Surprised Faces Validation Dataset Path"

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,  
    shear_range=0.2,  
    zoom_range=0.2,  
    horizontal_flip=True)  

validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(48, 48),  
    batch_size=32,
    color_mode='grayscale',  
    class_mode='categorical',  
    classes=['angry', 'surprise'])  

validation_generator = validation_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(48, 48),  
    batch_size=32,
    color_mode='grayscale',  
    class_mode='categorical',  
    classes=['angry', 'surprise'])
# Out:
# Found 7198 images belonging to 2 classes.
# Found 1757 images belonging to 2 classes.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
from keras.layers import Input

model = Sequential()
model.add(Input(shape=(48, 48, 1))) 
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(2, activation='sigmoid'))

# %%
# Modeli derle
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_21"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_84 (Conv2D)              │ (None, 46, 46, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_84 (MaxPooling2D) │ (None, 23, 23, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_85 (Conv2D)              │ (None, 21, 21, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_85 (MaxPooling2D) │ (None, 10, 10, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_86 (Conv2D)              │ (None, 8, 8, 128)      │        73,856 │
# ...

# %%
print("Train Generator - Dataset Size:", len(train_generator))
print("Validation Generator - Dataset Size:", len(validation_generator))
print("Batch Size:", train_generator.batch_size)
# Out:
# Train Generator - Veri Seti Boyutu: 225
# Validation Generator - Veri Seti Boyutu: 55
# Batch Boyutu: 32

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_data_dir = r"Angry and Surprised Faces Train Dataset"
validation_data_dir = r"Angry and Surprised Faces Validation Dataset"
classes = ['angry', 'surprise']

# %%
# CNN-Pooling 
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(2, activation='softmax')
])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(48, 48),
    batch_size=32,
    color_mode='grayscale',  
    class_mode='categorical',
    classes=classes)

validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(48, 48),
    batch_size=32,
    color_mode='grayscale',  
    class_mode='categorical',
    classes=classes)

history = model.fit(
    train_generator,
    steps_per_epoch=int(train_generator.samples/train_generator.batch_size),
    epochs=50,
    validation_data=validation_generator,
    validation_steps=int(validation_generator.samples/validation_generator.batch_size))
# Out:
# Found 7198 images belonging to 2 classes.
# Found 1757 images belonging to 2 classes.
# Epoch 1/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.5806 - loss: 0.6620 - val_accuracy: 0.7708 - val_loss: 0.4837
# Epoch 2/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 0s 233us/step - accuracy: 0.7188 - loss: 0.4711 - val_accuracy: 0.7931 - val_loss: 0.5259
# Epoch 3/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.7954 - loss: 0.4477 - val_accuracy: 0.8183 - val_loss: 0.4048
# Epoch 4/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 0s 187us/step - accuracy: 0.7812 - loss: 0.5970 - val_accuracy: 0.8621 - val_loss: 0.3238
# Epoch 5/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.8405 - loss: 0.3707 - val_accuracy: 0.7980 - val_loss: 0.4353
# Epoch 6/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 0s 215us/step - accuracy: 0.7500 - loss: 0.4915 - val_accuracy: 0.7931 - val_loss: 0.5512
# Epoch 7/50
# ...

# %%
# Dropout
model_with_dropout = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.4),  # Dropout frequency
    Dense(2, activation='softmax')
])
model_with_dropout.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history_with_dropout = model_with_dropout.fit(
    train_generator,
    steps_per_epoch=int(train_generator.samples/train_generator.batch_size),
    epochs=50,
    validation_data=validation_generator,
    validation_steps=int(validation_generator.samples/validation_generator.batch_size))
# Out:
# Epoch 1/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.5881 - loss: 0.6592 - val_accuracy: 0.7795 - val_loss: 0.4651
# Epoch 2/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 0s 273us/step - accuracy: 0.7500 - loss: 0.5220 - val_accuracy: 0.7586 - val_loss: 0.4705
# Epoch 3/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.8008 - loss: 0.4460 - val_accuracy: 0.8368 - val_loss: 0.3721
# Epoch 4/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 0s 196us/step - accuracy: 1.0000 - loss: 0.1576 - val_accuracy: 0.7586 - val_loss: 0.4436
# Epoch 5/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.8391 - loss: 0.3806 - val_accuracy: 0.8461 - val_loss: 0.3541
# Epoch 6/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 0s 195us/step - accuracy: 0.7500 - loss: 0.4707 - val_accuracy: 0.7931 - val_loss: 0.5188
# Epoch 7/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.8693 - loss: 0.3237 - val_accuracy: 0.8646 - val_loss: 0.3181
# Epoch 8/50
# ...

# %%
# Data Augmentation
train_datagen_augmented = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)
train_generator_augmented = train_datagen_augmented.flow_from_directory(
    train_data_dir,
    target_size=(48, 48),
    batch_size=32,
    color_mode='grayscale',  
    class_mode='categorical',
    classes=classes)

model_with_augmentation = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(2, activation='softmax')
])
model_with_augmentation.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history_with_augmentation = model_with_augmentation.fit(
    train_generator_augmented,
    steps_per_epoch=int(train_generator_augmented.samples/train_generator_augmented.batch_size),
    epochs=50,
    validation_data=validation_generator,
    validation_steps=int(validation_generator.samples/validation_generator.batch_size))
# Out:
# Found 7198 images belonging to 2 classes.
# Epoch 1/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.5648 - loss: 0.6715 - val_accuracy: 0.7309 - val_loss: 0.5330
# Epoch 2/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 0s 225us/step - accuracy: 0.7188 - loss: 0.4742 - val_accuracy: 0.7241 - val_loss: 0.5064
# Epoch 3/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.6906 - loss: 0.5746 - val_accuracy: 0.7604 - val_loss: 0.5111
# Epoch 4/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 0s 194us/step - accuracy: 0.7500 - loss: 0.5022 - val_accuracy: 0.8276 - val_loss: 0.4276
# Epoch 5/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.7421 - loss: 0.5296 - val_accuracy: 0.7882 - val_loss: 0.4665
# Epoch 6/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 0s 188us/step - accuracy: 0.7812 - loss: 0.5509 - val_accuracy: 0.7586 - val_loss: 0.4481
# Epoch 7/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.7603 - loss: 0.4922 - val_accuracy: 0.8229 - val_loss: 0.3920
# Epoch 8/50
# ...

# %%
#Use your best model, Save it as a keras file.
model.save("modelv1.keras")

# %%
# Dropout ve augmentation
model_with_dropout_and_augmentation = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.4), # Dropout frequency
    Dense(2, activation='softmax')
])
model_with_dropout_and_augmentation.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history_with_dropout_and_augmentation = model_with_dropout_and_augmentation.fit(
    train_generator_augmented,
    steps_per_epoch=int(train_generator_augmented.samples/train_generator_augmented.batch_size),
    epochs=50,
    validation_data=validation_generator,
    validation_steps=int(validation_generator.samples/validation_generator.batch_size))
# Out:
# Epoch 1/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.5469 - loss: 0.6848 - val_accuracy: 0.5660 - val_loss: 0.6655
# Epoch 2/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 0s 224us/step - accuracy: 0.5938 - loss: 0.6737 - val_accuracy: 0.5862 - val_loss: 0.6538
# Epoch 3/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6223 - loss: 0.6508 - val_accuracy: 0.7228 - val_loss: 0.5431
# Epoch 4/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 0s 186us/step - accuracy: 0.7500 - loss: 0.6035 - val_accuracy: 0.7586 - val_loss: 0.5083
# Epoch 5/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7099 - loss: 0.5687 - val_accuracy: 0.7662 - val_loss: 0.4940
# Epoch 6/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 0s 202us/step - accuracy: 0.6562 - loss: 0.7563 - val_accuracy: 0.6207 - val_loss: 0.6668
# Epoch 7/50
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.7389 - loss: 0.5354 - val_accuracy: 0.7969 - val_loss: 0.4412
# Epoch 8/50
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

# %%
# Accuracy Graph For CNN-Pooling Model
plt.figure(figsize=(10, 5))
plt.plot(range(1, len(acc) + 1), acc, label='Training Accuracy (CNN)', color='blue')
plt.plot(range(1, len(val_acc) + 1), val_acc, label='Validation Accuracy (CNN)', color='cyan')
plt.title('Training and Validation Accuracy (Normal Data)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
acc_with_dropout = history.history['accuracy']
val_acc_with_dropout = history.history['val_accuracy']

# %%
# Accuracy Graph For Dropouted Model
plt.figure(figsize=(10, 5))
plt.plot(range(1, len(acc_with_dropout) + 1), acc_with_dropout, label='Training Accuracy (Dropout)', color='green')
plt.plot(range(1, len(val_acc_with_dropout) + 1), val_acc_with_dropout, label='Validation Accuracy (Dropout)', color='lime')
plt.title('Training and Validation Accuracy (Dropout Applied)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
acc_with_augmentation = history.history['accuracy']
val_acc_with_augmentation = history.history['val_accuracy']

# %%
# Accuracy Graph For Data Augmentationed Model
plt.figure(figsize=(10, 5))
plt.plot(range(1, len(acc_with_augmentation) + 1), acc_with_augmentation, label='Training Accuracy (Augmentation)', color='red')
plt.plot(range(1, len(val_acc_with_augmentation) + 1), val_acc_with_augmentation, label='Validation Accuracy (Augmentation)', color='orange')
plt.title('Training and Validation Accuracy (Data Augmentation Applied)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
acc_with_dropout_and_augmentation = history.history['accuracy']
val_acc_with_dropout_and_augmentation = history.history['val_accuracy']

# %%
# Accuracy Graph For Dropouted and Data Augmentationed Model
plt.figure(figsize=(10, 5))
plt.plot(range(1, len(acc_with_dropout_and_augmentation) + 1), acc_with_dropout_and_augmentation, label='Training Accuracy (Dropout + Augmentation)', color='purple')
plt.plot(range(1, len(val_acc_with_dropout_and_augmentation) + 1), val_acc_with_dropout_and_augmentation, label='Validation Accuracy (Dropout + Augmentation)', color='magenta')
plt.title('Training and Validation Accuracy (Dropout + Data Augmentation Applied)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Face Recognition with Camera

# %%
import cv2
from tensorflow.keras.models import load_model
import numpy as np

# %%
# Face Recognition Model
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
# Emotion Recognition Model(Use Your Best Model)
emotion_model = load_model('modelv1.keras')

# %%
# Emotion Labels
emotion_labels = ['angry', 'surprise']

# %%
# Camera Access
cap = cv2.VideoCapture(0)

# %%
while True:
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect Faces
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)

    for (x, y, w, h) in faces:
        face_roi = gray[y:y+h, x:x+w]
        resized_roi = cv2.resize(face_roi, (48, 48))
        normalized_roi = resized_roi / 255.0
        reshaped_roi = np.reshape(normalized_roi, (1, 48, 48, 1))

        # Emotion Recognition Part
        prediction = emotion_model.predict(reshaped_roi)
        max_index = np.argmax(prediction[0])
        emotion_label = emotion_labels[max_index]

        # Draw a box around the face and write the emotion label
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
        cv2.putText(frame, emotion_label, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)
        
        # Show results
    cv2.imshow('Emotion Recognition', frame)
        
        #Press "q" to exit the Recognition Mode
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ...

# %%
# Close the Camera
cap.release()
cv2.destroyAllWindows()
